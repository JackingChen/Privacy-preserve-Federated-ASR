# %%
import torch
import numpy as np
from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union
import os.path
import pandas as pd
from datasets import Dataset, load_from_disk
import librosa
from datasets import load_dataset, load_metric
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor, Trainer, TrainingArguments
from transformers import Data2VecAudioConfig, HubertConfig, SEWDConfig, UniSpeechSatConfig
from transformers import Data2VecAudioForCTC, HubertForCTC, SEWDForCTC, UniSpeechSatForCTC
from jiwer import wer
import scipy.io
import argparse
import os
import pandas as pd
from datasets import Dataset, load_from_disk
import librosa
import scipy.io.wavfile
import numpy as np
# from utils import csv2dataset, WriteResult

# =======================================
# 有一些common的function丟到這邊
# =======================================
parser = argparse.ArgumentParser()
#parser.add_argument('-model', '--model_path', type=str, default="./saves/wav2vec2-base-960h_GRL_0.5", help="Where the model is saved")
parser.add_argument('-opt', '--optimizer', type=str, default="adamw_hf", help="The optimizer to use: adamw_hf, adamw_torch, adamw_apex_fused, or adafactor")
parser.add_argument('-MGN', '--max_grad_norm', type=float, default=1.0, help="Maximum gradient norm (for gradient clipping)")
parser.add_argument('-model_type', '--model_type', type=str, default="data2vec", help="Type of the model")
parser.add_argument('-sr', '--sampl_rate', type=float, default=16000, help="librosa read smping rate")
parser.add_argument('-lr', '--learning_rate', type=float, default=1e-4, help="Learning rate")
parser.add_argument('-RD', '--root_dir', default='/mnt/Internal/FedASR/Data/ADReSS-IS2020-data', help="Learning rate")
parser.add_argument('--AudioLoadFunc', default='librosa', help="用scipy function好像可以比較快")
args = parser.parse_args(args=[])
# from utils import csv2dataset
def ID2Label(ID,
            spk2label = np.load("/mnt/Internal/FedASR/weitung/HuggingFace/Pretrain/dataset/test_dic.npy", allow_pickle=True).tolist()):
    name = ID.split("_")                                                    #  from file name to spkID
    if (name[1] == 'INV'):                                                  # interviewer is CC
        label = 0
    else:                                                                   # for participant
        label = spk2label[name[0]]                                          # label according to look-up table
    return label                                                            # return dementia label for this file
def prepare_dataset(batch):
    audio = batch["array"]

    # batched output is "un-batched" to ensure mapping is correct
    batch["input_values"] = processor(audio, sampling_rate=16000).input_values[0]
    
    with processor.as_target_processor():
        batch["labels"] = processor(batch["text"]).input_ids
    return batch
def csv2dataset(audio_path = '{}/clips/'.format(args.root_dir),
                csv_path = '{}/mid_csv/test.csv'.format(args.root_dir)):
    stored = "./dataset/" + csv_path.split("/")[-1].split(".")[0]
    if (os.path.exists(stored)):
        print("Load data from local...")
        return load_from_disk(stored)
 
    data = pd.read_csv(csv_path)                                                # read desired csv
    dataset = Dataset.from_pandas(data)                                     # turn into class dataset
    
    # initialize a dictionary
    my_dict = {}
    my_dict["path"] = []                                                    # path to audio
    my_dict["array"] = []                                                   # waveform in array
    my_dict["text"] = []                                                    # ground truth transcript
    my_dict["dementia_labels"] = []

    spk2label=np.load("/mnt/Internal/FedASR/weitung/HuggingFace/Pretrain/dataset/test_dic.npy", allow_pickle=True).tolist()

    i = 1
    for file_path in dataset['path']:                                            # for all files
        if dataset['sentence'][i-1] != None:                                # only the non-empty transcript
            if args.AudioLoadFunc == 'librosa':
                sig, s = librosa.load('{0}/{1}'.format(audio_path,file_path), sr=args.sampl_rate, dtype='float32')  # read audio w/ 16k sr
            else:
                s, sig = scipy.io.wavfile.read('{0}/{1}'.format(audio_path,file_path))
                sig=librosa.util.normalize(sig)
            if len(sig) > 1600:                                             # get rid of audio that's too short
                my_dict["path"].append(file_path)                                # add path
                my_dict["array"].append(sig)                                # add audio wave
                my_dict["text"].append(dataset['sentence'][i-1].upper())    # transcript to uppercase
                my_dict["dementia_labels"].append(ID2Label(ID=file_path,
                                                           spk2label=spk2label))
        print(i, end="\r")                                                  # print progress
        i += 1
    print("There're ", len(my_dict["path"]), " non-empty files.")

    result_dataset = Dataset.from_dict(my_dict)
    result_dataset.save_to_disk(stored)                                     # save for later use
    
    return result_dataset
def map_to_result(batch,*,  model=None, processor=None):
    with torch.no_grad():
        input_values = torch.tensor(batch["input_values"]).unsqueeze(0)
        logits = model(input_values).logits

    pred_ids = torch.argmax(logits, dim=-1)
    batch["pred_str"] = processor.batch_decode(pred_ids)[0]
    batch["text"] = processor.decode(batch["labels"], group_tokens=False)
  
    return batch
def WriteResult(result,Save_path):
    df_results=pd.DataFrame([result['text'],result['pred_str']], index=['GroundTruth','PredStr']).T
    df_results.to_csv('{}/Result.csv'.format(Save_path))
    print("Writing results to {}".format(Save_path))
model_type="data2vec"
name='facebook/data2vec-audio-large-960h'
rootdir='/mnt/Internal/FedASR/Data/ADReSS-IS2020-data'
test_data = csv2dataset(audio_path = '{}/clips/'.format(rootdir),
                        csv_path = "{}/mid_csv/test.csv".format(rootdir))
processor = Wav2Vec2Processor.from_pretrained(name)
test_data = test_data.map(prepare_dataset, num_proc=4)
# load in trained model
if model_type == "wav2vec":
    new_model = Wav2Vec2ForCTC.from_pretrained("./saves/" + name.split("/")[-1] + "_finetuned/final")
    new_processor = Wav2Vec2Processor.from_pretrained(name)
elif model_type == "data2vec":
    mask_time_prob = 0                                                                     # change config
    config = Data2VecAudioConfig.from_pretrained(name, mask_time_prob=mask_time_prob)
    model = Data2VecAudioForCTC.from_pretrained(name, config=config)
    new_model = Data2VecAudioForCTC.from_pretrained("./saves/" + name.split("/")[-1] + "_finetuned/final")
    new_processor = Wav2Vec2Processor.from_pretrained(name)
elif model_type == "hubert":
    new_model = HubertForCTC.from_pretrained("./saves/" + name.split("/")[-1] + "_finetuned/final")
    new_processor = Wav2Vec2Processor.from_pretrained(name)
elif model_type == "sewd":
    new_model = SEWDForCTC.from_pretrained("./saves/" + name.split("/")[-1] + "_finetuned/final")
    new_processor = Wav2Vec2Processor.from_pretrained(name)
elif model_type == "unispeech":
    new_model = UniSpeechSatForCTC.from_pretrained("./saves/" + name.split("/")[-1] + "_finetuned/final")
    new_processor = Wav2Vec2Processor.from_pretrained(name)
else:
    print("WRONG TYPE!!!!!!!!!!!!!!!!")
Save_path="./saves/" + name.split("/")[-1] + "_finetuned/final"

# 在 datasets 模組中，map 函式並不支援直接將額外引數傳遞給映射函式。您可以使用其他方式來實現在 map_to_result 函式中傳遞 model 和 processor。
# 在使用 map 函式時，可以將 model 和 processor 作為函式引數傳遞給 map_to_result 函式
# lambda arguments: expression
result = test_data.map(lambda batch: map_to_result(batch, model=model, processor=processor))
result_newmdl = test_data.map(lambda batch: map_to_result(batch, model=new_model, processor=new_processor))


print("WER of ", name, " : ", wer(result["text"], result["pred_str"]))
WriteResult(result,Save_path)
print("DONE!")
# Out:
# Load data from local...
# Loading cached processed dataset at /home/FedASR/dacs/centralized/dataset/test/cache-1b7e3673b55144b2_*_of_00004.arrow
# Some weights of the model checkpoint at facebook/data2vec-audio-large-960h were not used when initializing Data2VecAudioForCTC: ['data2vec_audio.masked_spec_embed']
# - This IS expected if you are initializing Data2VecAudioForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Data2VecAudioForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]
# WER of  facebook/data2vec-audio-large-960h  :  0.4746268656716418
# Writing results to ./saves/data2vec-audio-large-960h_finetuned/final
# DONE!

# %%
result = test_data.map(lambda batch: map_to_result(batch , model=model, processor=processor), num_proc=4)
# Out:
# Map (num_proc=4):   0%|          | 0/800 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2261200/330085998.py in <module>
# ----> 1 result = test_data.map(lambda batch: map_to_result(batch , model=model, processor=processor), num_proc=4)
#       2
#
# ~/.conda/envs/Flower-speechbrain/lib/python3.7/site-packages/datasets/arrow_dataset.py in wrapper(*args, **kwargs)
#     561             self: "Dataset" = kwargs.pop("self")
#     562         # apply actual function
# --> 563         out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     564         datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     565         for dataset in datasets:
#
# ~/.conda/envs/Flower-speechbrain/lib/python3.7/site-packages/datasets/arrow_dataset.py in wrapper(*args, **kwargs)
#     526         }
#     527         # apply actual function
# --> 528         out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     529         datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     530         # re-apply format to the output
#
# ~/.conda/envs/Flower-speechbrain/lib/python3.7/site-packages/datasets/arrow_dataset.py in map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3096                     ) as pbar:
#    3097                         for rank, done, content in iflatmap_unordered(
# -> 3098                             pool, Dataset._map_single, kwargs_iterable=kwargs_per_job
#    3099                         ):
#    3100                             if done:
#
# ~/.conda/envs/Flower-speechbrain/lib/python3.7/site-packages/datasets/utils/py_utils.py in iflatmap_unordered(pool, func, kwargs_iterable)
#    1370         while True:
#    1371             try:
# -> 1372                 yield queue.get(timeout=0.05)
#    1373             except Empty:
#    1374                 if all(async_result.ready() for async_result in async_results) and queue.empty():
#
# <string> in get(self, *args, **kwds)
#
# ~/.conda/envs/Flower-speechbrain/lib/python3.7/site-packages/multiprocess/managers.py in _callmethod(self, methodname, args, kwds)
#     817
#     818         conn.send((self._id, methodname, args, kwds))
# --> 819         kind, result = conn.recv()
#     820
#     821         if kind == '#RETURN':
#
# ~/.conda/envs/Flower-speechbrain/lib/python3.7/site-packages/multiprocess/connection.py in recv(self)
#     251         self._check_closed()
#     252         self._check_readable()
# --> 253         buf = self._recv_bytes()
#     254         return _ForkingPickler.loads(buf.getbuffer())
#     255
#
# ~/.conda/envs/Flower-speechbrain/lib/python3.7/site-packages/multiprocess/connection.py in _recv_bytes(self, maxsize)
#     408
#     409     def _recv_bytes(self, maxsize=None):
# --> 410         buf = self._recv(4)
#     411         size, = struct.unpack("!i", buf.getvalue())
#     412         if maxsize is not None and size > maxsize:
#
# ~/.conda/envs/Flower-speechbrain/lib/python3.7/site-packages/multiprocess/connection.py in _recv(self, size, read)
#     380         remaining = size
#     381         while remaining > 0:
# --> 382             chunk = read(handle, remaining)
#     383             n = len(chunk)
#     384             if n == 0:
#
# KeyboardInterrupt:

# %%
result['pred_str']
# Out:
# ["MOTHER'S GETTING HER FEET WET",
#  '',
#  'NO',
#  'WITH A COUPLE OF BOWLS AND A PLATE ON THE E COUNTER',
#  'EVERYTHING THAT YOU SEE HAPPENING HERE',
#  "THEY'RE GETTING IN THE COOKIE JAR AND THEIR UPSETTING THE STOOL",
#  "AUNT MIE'S HAND MORSOM QUICKLY",
#  "THER'S NOTING THERE OUTSADE HE AS POSHESS",
#  'THE GIRL IS REACHING FOR A COOKIE',
#  '',
#  "THERE'S A CUP TWO CUPS AND A SAUCER ON THE SINK",
#  'THE GODDESS THE CUPS WER TI HER MESE AN DWIS WEN SHE GAN SIT ON HIS OWNESID',
#  'BU A BOY WITH E COOKI IN HIS ONE HAND AND HIS HAND IN THE COFFEE JAR',
#  'O',
#  'SIX RUNNING OVER',
#  'I LIKE THESE THINGS AND TRO HERE',
#  '',
#  'A LITTLE BOY IS GETTING HIMSELF IN THE CRUBBIES ADDED JA',
#  "EEMS TO ME THAT THAT'S ESSENTIALLY THE THINGS THAT ARE GOING ON IN THIS PICTURE",
#  'IT THAT THE STORE WAS TEPPING OUT',
#  'HIS',
#  'AND THE LITTLE GIRL HAS HER FINGER UP TO HER MOUTH TO BE QUIET',
#  'HIS PICTURE',
#  "AH SHE'S HOLDING THE DISHCLOTH IN HER RIGHT HAND AND THE PLATE SHE IS DRYING IN HER LEFT",
#  'AND THE BOY IS STANDING ON A STOOL WHICH IS TIPPING OVER',
#  'AH THE LITTLE BOY IS REACHING FOR A POOKY',
#  'AND YOU CAN SEE ANOTHER WINDOW AND SOME BUSHES OUT THERE AN THE TREE',
#  '',
#  "WELL THE HANDLES ON THE DOOR ARE THE KIND THEY'RE JUST A ALMOST LIKE A ROUND PIECE OF WOOD THAT YOU HAVE TO GET HOLD OF TO PULL HE CUPBOARD DOOR OPEN",
#  '',
#  'ABA YOU SEE WHAT MEANT GOING ON ON THERE',
#  'O KA THE WATER IS RUNNING OUT OF THE SINK OVERFLOWING',
#  'HER',
#  'O ANYTHING ELSE',
#  'IN THE FIRST PLACE THE MOTHER FORGOT TO TURN OFF THE WATER AND THE WATER IS RUNNING AFTER TINK',
#  "BREK'S BACK I SHOOK HIS HEAD",
#  'EPICLY ON ON',
#  '',
#  'YOU MENMOD NOTHING BELIKE ITY AFFACTION',
#  'FINE',
#  "YES HE'S HE'S TRYING TO GET THE KAT DOWN WHERE I S'PPOSE SHE CAN SHARE WITH HIM",
#  'BATEME BE SURE',
#  'ERPERE',
#  '',
#  'AND OUTSIDE IS A NICE GARDEN WITH A PATH LEADING AROUND THE HOUSE AND BUSHES AND SHRUBS AND GRASS GROWING AROUND',
#  "YOU JUST REPEAT THE ANTO HERD AFTER I'M POURING MOR STROL",
#  'J SPILLING WATER ALL OVER THE FLOOR',
#  "I DON'T SEE ANYTHING ELSE THERE",
#  'TO',
#  'WEUNDERSTANDING THERE FOR AWHILE',
#  'I AG ONE EIGHT',
#  'YES THE THIRD RAT',
#  'IN IN HERE WHEN THEY HAD SO STUCK IN THROUGH HERE',
#  'O',
#  "THAT'S AWFULLY HARD FOR A NEEDLE MISS COOLER",
#  'E KIT FALLING OFF THE STOOL',
#  'SHE HAS WHAT FAITH STANDING IN THE WATER',
#  'AND THE MOTHER MUST BE LOOKING OUT THE WINDOW BECAUSE THE SINK IS SPILLING OVER WITH WATER OVERFLOWING WITH WATER',
#  'NOCAY',
#  'LITTLE GIRL WONT ONE',
#  'EM AH ME SCAN A LITTLE BIT MORE',
#  'HIS FALLING OFF THE STOOL',
#  "AND THERE'S THE PICTURE",
#  '',
#  '',
#  'TE FORT O THING',
#  'AI DID ANT NONSENSIB ON TONI',
#  'NO REALLY THOSE ARE THE ONLY ACTIVITIES I SEE',
#  'BE A PISTOS',
#  'ANDFIRTWS',
#  "SHE'S DRYING A DIS",
#  'IPIPITA',
#  'BUT THEY PUT THAT STUFF ARONDIN AIR',
#  'ATOGT',
#  "YOU DON'T HAVE TO READ IT JUST LOOK AT THE PICTURE",
#  'A GOOD WAY TO BREAK HIS NECK',
#  "THEE'RE TWO CUPS AND A DISH I PRESUME THAT'S A DISH SAID ER ALREADY DRIED I GUESS AND SITTING ON THE SIDE OF THE SINK",
#  "AND HE STOOLIST TURNIN OVER ON HIM BUT HE'S STANDING ON",
#  'HES TO GIVE ME A DIFFERENT',
#  '',
#  'DAD CALLED AND SAID HE WOULD BRING HOME A PILASCER FOR DINNER MID THE CURTAINS OF BRAWING LAWN',
#  "THERE'S A WA",
#  'KIDS GRO HEAD ON THE FLOOR',
#  "HERE THE BOY THE STEP LADDER'S TURNIN UNDER HIS LEGS AND HE'S STEALING COOKIES OF THE COOKY JAR",
#  '',
#  '',
#  'TESIS FOR BIN ATOF LIKE',
#  'HAND IN TEM A THEY SEEM OBLIVIOUS TO THE WATERFALL LE A BOAT FLOI',
#  'AND THE MOTHER IS DOING DISHES',
#  'YER ON YIS PAPER',
#  'CUPBOARD DOOR IS OPENED',
#  'OTHE ADLS AR CAF DRAWERS AND E COUNTERPATS ET CETERA',
#  'ISTHAT ALL HE ASKED',
#  'WATER IS RUNNING IN TI',
#  "CAN YOU TELL ME ANYTHING ELSE THAT'S GOING ON OVER THERE",
#  'I THINK SHES RUNNING WATER',
#  'AND O TWO CUPS AND A PLATE ON THE COUNTER',
#  'HEM GIRL A TIE TE GLANDAS DISHES AH',
#  '',
#  'ASINTISING WITH RUNNING OVER',
#  'VARY RI',
#  '',
#  "AND THE WATER'S RUNNING OUT O THE SINK",
#  '',
#  'ANYTHING ELSE',
#  'OA THE BOY THE BOY TANDING ON HIS CHAIRS AT HIS HIHN TARTING TOP ALL OVER',
#  'TE MAD SFALLEN OFF THE COOKED ROER',
#  'OAR',
#  'KID NIGHT',
#  'MOBER',
#  '',
#  'WHAT ELSE IS INE',
#  'MIS MATBEL',
#  'AN MAE OS BED BE ON IS BED',
#  "AND WHAT'S REALLY STRANGE IS TIT CAN'T SEE ANY HANDLES ON THE CUPBOARDS ON THE OTHER SIDE OF THE KITCHEN",
#  'THE DISHES THAT SHES THROUGH DRYING ARE SITTING ON THE SINK TOP',
#  'THERE ARE THINGS GROWING OUT THERE',
#  "ON THE OTHER ROUND THE CORNER OF THE KITCHEN A A THERE'S A COUNTER THAT SORT OF TURNS A CORNER",
#  'BIS',
#  'ANT THE YOUNGSTER TERE HEIN GIVINLY TEA',
#  'O CES SUT FAN E AF AN ACCIDENT',
#  'SEPOSON MURCHANT DISHES',
#  'COOKIES IN TE COOKYE JAR WITH THE LID OFF',
#  'WINDOWS UP AT LOOKS LIKE',
#  'OWA I DI THE SORT OF A THING',
#  "THE MOTHER IS A WASHING DISHES AND THE WATER'S SPILLING OVER ON THE E KITCHEN FLOOR",
#  'THE YOUN',
#  'THE WINDOWS ARE OPEN',
#  "AND THEY'RE GETTING SOMETHING TO EAT HERE",
#  'TGARDEN AGAINST',
#  'WHAT ELSE IS HAPPENING',
#  'AY A LAD STANDING ON A STOOL TEERING GRABBING HATTHE COOKINS',
#  'NOW SNAKE',
#  "IF IT'S RULNINOBERRATHER",
#  '',
#  'WATER HISGRINNIN OVERFLOWING',
#  'HETOGHT TAKING PUSPY DOWN TA COOKINGCAND COOKY JAR',
#  'LOOK AT THIS PICTURE',
#  'I E ET LON THINK',
#  'TET LONGE WE TA E STORES O ESON FAR STONE',
#  'WELL IS HAPPENS TO BE A KITCHEN',
#  'AND THE TWO CHILDREN ARE HOPING THAT MAMMA WILL NOT NOTICE BECAUSE SHE IS LOOKING OUT THE WINDOW THAT THEY ARE GETTING INTO THE COOKYE JAR',
#  'AND HIS CHAIR SLIPPING OUP FROM ANOTHER STOVE SLIPPING OUP FROM UNDER HIM',
#  '',
#  'THEREIS ANY THEY ASK',
#  'O',
#  'IBOS ETE OR TIRTY',
#  'THA TIN WEVS HIS FULLO FLOWING ON FORWADAN',
#  "I'D LIKE YOU TO TELL ME ALL THE THINGS YOU SEE GOING ON IN POPORTION",
#  'OH THEN MESIDES',
#  '',
#  "NOW I'M GOING TO SHOW YOU A PICTURE",
#  'TES WAS OVERLOWIN',
#  'WHO WO FIIT',
#  'A WAY THE',
#  'AH THE BOY IS REACHING INTO THE COOKIE JAR',
#  'TOP CABINETS THE DOOR IS OPENED AND THE COOKING JAR IS IN THE CABINT',
#  "LIBOY'S GETTING COOKIES AND HE'S FALLING",
#  '',
#  'THAT THE DOOR IS OPEN',
#  'HM INCO TALL IN GONO T',
#  'LITTLE BOYS GIT IN A CROOKED JA',
#  'WITHOUT ALL THE ACTON',
#  "I DON'T KNOW",
#  'THERE ARE TIED BACK CURTAINS AT THE WINDOW',
#  'I A EPENROBE OEMEN YO CAN',
#  'THEN THROWING THE WATER IN THE KITCHEN SANK',
#  'AND SPLASHING ON THE FLOOR',
#  'COOPY JAR HIP A LITTLE',
#  'AH IN VIEW OF THE YARD FROM THE KITCHEN SEDE CURTAIN',
#  'AND IF THE CANCIO IS THE SAME TYPEANSER AR THOU STILEBOTIEN O',
#  '',
#  'SIR FOOTNOE NINE FIF TOSN',
#  'UN HE SORT O CUT DOWN THE PLATE',
#  "I DON'T KNOW WHAT THE HAND MEANS TO THE MOUTH",
#  'TIS DISHES TODICIOUS DOCTOR',
#  'O Q',
#  'TER WE AL THE ACTION INDEBTED',
#  'OH TA',
#  'IAN O BOY WORE NOSO LES WON CRACKA TO ON THE BACK OF THAT CI TITIN QICKLASON',
#  'THE STORLE WAS FALLING OVER',
#  'TELL EVERYTHING THAC HAPPEN  OW',
#  'AMPEI',
#  'NO',
#  'THE SINK IS RUNNING OVER',
#  'AN SMISON WENT OFF SLIPI WAOEAG',
#  'GO AHEAD',
#  '',
#  'THE CUPBOARD DOORS',
#  "THERE'S SOMETHIN BUT I DON'T KNOW WHAT IT IS WRITTEN ON THE GRASS IT SEEMS",
#  'O',
#  "AND O HE' STANDING ON A THREE LEGGED STOOL AND IS LOSING HIS BALANCE AND ABOUT TO FALL ON THE FLOOR",
#  "THAT'S IT T GIE ME SOMETING PIT",
#  'UNDER HER FEET',
#  '',
#  '',
#  'TO AT WIT',
#  "MUM'S MAD AT THEM BCAUSE THEY'VE ROPED LOG ITO TAN OTEN",
#  'TELL ME EVERYTHING THAT YOU SEE GOING ON IN THISPOT',
#  '',
#  "AH YER'S IN E BRAND",
#  'I IG I ASK YOU TO TAKE A LOOK AT THIS PICTURE',
#  "AND A THERE'SE A DRAPES ON THE KITCHEN AN CURTAINS ON THE KITCHEN ANDE THE CABINETS ALL AROUND THE SINK",
#  "TAKE A LOOK AT THAT PICTURE AND TELL ME EVERYTHING THAT'S GOING ON IN THAT PICTURE EVERYTHING THAT YOU SEE HAPPENING THERE",
#  "WELL THE KINS WON'T FALL OFF",
#  '',
#  "SHE'S DRYING THE DISHES AND LETTING THE WATER PA KEEPIN KEEP ON RUNNING IN  IN THE SINK",
#  'HE ADVANCED AND STEP OUTSIDE',
#  'MISS SISTERIS TELLD HEM TO BE QUIET',
#  "AND THE WATER'S FALLEN DOWN ON TO THE FLOOR",
#  'TEYE MOTHER IS WASHING DISHES',
#  "IT'S APPARENTLY SOMEWHERE OUTSIDE BECAUSE THE WINDOW'S OPEN OR LOOKS LIKE SHRUBS ARE GROWING",
#  '',
#  "AH F SHE'S PUT HER FINGER TURL HER LIPS",
#  'O',
#  'WHAT HAS GONE ALL MOR',
#  'THE CURTAINS OF THE WINDOWS',
#  'ALER',
#  'TWO',
#  'AH THE WIND IS OPEN AND I WOULD SAY THE WIND IS BLOWING',
#  'GIV ME FE PESEN DOWN TO',
#  "WELL LET'S SEE",
#  'A DEAR',
#  'AND THE BOY IS ON A STOOL WHICH IS FALLING OVER TO GET IN THE COOKI JAR UP ON THE SECOND SHELF OF THE CUPBOARD WITH THE DOOR O',
#  'THE LIAD IS OFF THE COOKY JAR',
#  'O WE ALL BE AT',
#  'I ATIT',
#  'I GOL AN HAV E GO  BOAY I TECORK',
#  'SO THE BOY CLIMBS UP ON A STOOL TO REACH THE COKIJA',
#  'OTE WHA',
#  "THE WATER IS RUNNING OVER AND SHE'S STANDING IN THE SAND AND THE WATER BA SA RUNNING OVER",
#  'THE GIRL CRYING  SHE WANTS YO CIRKI',
#  "HE GIRLAS LOOKS LIKE SHE'S LAUGHING",
#  'THE YOUNG LADY IS HOLDING HER HAND UP READY TO RECEIVE ONE OF THE COOKIES',
#  'A WOULD BE LOF DETY ITSE BEFORE DEE SIEK A THIS WATERS RUN OUT OF S THICKET',
#  'NOB',
#  "SHE'S GRINED THE DISHES",
#  'KIDS CLIMBIN UP ON THE STOOL AND REECHIN UP IN THE COPVARD',
#  'FALLEN ON THE FLOOR',
#  "AND THEN SHE'S LOOKING OUT O WINDOW",
#  'DRYNADUK',
#  "AND SHE'S STANDING THERE",
#  'STHANK YOU SACHAP',
#  'LICE CURTAINS PULLED BACK',
#  'THE MOTHERS DOING THE DISHES',
#  'THE WINDOW',
#  'OTHER FORANED DRYING PETITIONS',
#  'E GIRL IS REACHING FOR OUR COOKIE',
#  "WHAT'S HAPPENING IN THAT PICTURE",
#  "DON'T YOU SEE GOING ON IN THE PRINTTUR",
#  "HE'S REACHING UP TO GET IT BUT I DON'T SEE ANYTHING WRONG WITH HERKE THOUGH",
#  "LOOKS AS THOUG THERE'S SOME SADS AN OME FISHES IN THE SINK",
#  'AND I SAY',
#  'AND THE LADIES DRYING A PLATE',
#  'MICE BOOTH AND TERANDER',
#  'SOMEBOY GETTING ON IN THE PICTUR',
#  'ANYTHING',
#  '',
#  'SHESBER',
#  'I GET THAT',
#  "HE'S HANDING ONE DOWN TO HIS SISTER",
#  "AH HIS MOTHER IS STANDING IN A PUDDLE OF WATER BECAUSE SHE DIDN'T TURN OFF THE FORCET AND SHE'S TRYING TO DRY A",
#  "IT'S A FAMILY AFFAIR MOTHER AND THE CHILDREN",
#  'ER PAT',
#  'DIAR GA TRIPARTNA STORM THE TRIPLE SORISHE SAD THE ROCKE HEADED',
#  "THAT'S ABOUT IT",
#  "HIS LITTLE SISTER IS REACHING FOR A PUFFI AND I THINK BEGINNING TO LAUGH BECAUSE HE'S FALLING",
#  'YE',
#  'HE SURVIVED ANYWAY',
#  'ANOR',
#  'BUT WE NOT PERMATED TO',
#  "THERE'S A LITTLE SCOLLIK BALANCE ACROSS THE TOP OF THE CURTAINS",
#  'WILDLY  WEN THE BOY IS SELLING COOKIES  GIVE IT TO HIS FRIEND OR SISTER',
#  'WE',
#  'TO OW THE AFTERNOON APPROACHED',
#  'WHAT DO YOU SEE GOING ON IN THAT PICURE',
#  'JUST A LID THINKIT FOR ME ALLIS TO GO ON',
#  'WELL INTO THE COSKE JAR IN THE DE YEA TORWORT FALLING DOWN',
#  '',
#  'I SEE THE OTHER ACTION',
#  '',
#  'I SEE THE WOMAN IN A PICTURE',
#  "MOTHER IS A HOLDING A DISHCLOTH T SHE'S DRYING THE DISHES",
#  'O IS YOR MORE',
#  "OFGENS ON PASE BUT SHE'S THINKING A SHOULD AVE HE KIDS OR BEHIND",
#  'YOU MAY MIKE THE WOMAN DOING THE DISHES AND THE WATER BURNING OVER IN THE SINK',
#  'WHAT HEW DO I KNOW',
#  '',
#  'AND AH',
#  'THE WATER IS FLOWING RUNNING AND FLOWING OUT OF THE SINK',
#  '',
#  "AND THE MOTHER OH BOY THE WATER'S OFF PILL NOW THE SINK",
#  'O',
#  '',
#  'WAL',
#  'MOTHER IS LOOKING OUT THE WINDOW',
#  '',
#  'SAD NO',
#  'CAN SEE A WINDOW IN THE OTHER PART OF THE HOUSE',
#  'UPSET THE WATER  SINK',
#  'HARD BUT IS USED HAVING MOR POWER OF THE FINGER TO THE LIPS',
#  'SHE OUGHT TO DRY HER FEET INSTEAD',
#  'HOPE IT MAY LIB THE LINOU SEE THROUGH THE KITCHEN IK ON I STILES IT',
#  'TANKO',
#  'O ANYTHING ELSE GOING ON IN THAT FISSIER',
#  'TEIN GINTEE ANTE GRIN ALMA MADE THAT SO VORMER',
#  'WEL NATURALLY THE STOLE IT FALLS OVER THE BOY IS GOING TO FALLON FLOOR',
#  'AH MOTHER IS FROWNING',
#  'LITTLE GIRLS BETTER STAND UP FOR ONE',
#  "AN I DON'T KNOW THAT THERE'S ANYTHING SPECIAL GOING ON OUTSIDE THE WINDOW",
#  'WOTH MY FOOT WHICH A POK AJARN MY BANGING TABLE I  DOR',
#  '',
#  'TO',
#  'AND THE MOTHER OF THE HOUSE IS WASHING THE DISHES',
#  'I RELDY  TIN AN',
#  '',
#  'MAYOTAD SHE WAS LUCKY EITHER SUS THAT REASON AFFORD',
#  'KIN',
#  "SHE'S WASHIN DISHES AND THE WATER'S RUN ALL OVER THE FLOOR",
#  "IT'S JUST WHAT'S GOING ON",
#  "JUST TELL ME WHAT'S HAPPENING IN THE",
#  'ISVAT',
#  'I WANT YOU TO TELL ME EVERYTHING THAT YOU SEE GOING ON IN THIS PICTURE',
#  "I THINK I'VE RUN OUT OF",
#  'AND WE LESS TAN THE FIRST ONE',
#  'KNO ME ALL THEER',
#  'NOW THERE IT IS',
#  'AND ONE YOU SNEAPING ANOTHER ONE',
#  'AN EXIBITED',
#  'NOT IET',
#  'SE SIR',
#  'POQU',
#  'THE MOTHERAS DRYING E DISHES FROWNING BUT NOT TURNING OFF THE FAUCET',
#  'O DOE E CANNERS POVATIN',
#  'ALL THE ACTION THAT YOU CAN SAY',
#  'ON BESIDE THE SINK THERE ARE TWO CUPS AND A PLATE',
#  'SHE STEPPED INTO THE WATER',
#  "IT'S GOIN ALL AWAY DOWN IN HERE",
#  'SHE DRIED A DISH',
#  'HESN COUSH ME ME FALL OFF THE STOOL',
#  'SAD E',
#  'WOL YEYERSONSIND WHEN THE',
#  'THE LITTLE GIRL IS LAUGHING AT THE BOY FALLING OFF THIS CHEER',
#  'I SEE E TWO KIDS I WITH THE COOKIE JAR ONE ON A STOOL THE OTHER STANDING ON THE FLOOR',
#  'OK BOYS IN THE COOKIE JARS',
#  'SA',
#  '',
#  'TO THIRTY MIN',
#  'EVERYTHING MUS HAPPEN',
#  'NOT',
#  'AND THE GIRL',
#  'START WHENEVER YOU LIKE',
#  'ONE O ONIS DIT AN CHO COGISH COOKAGE JAR IN THE CABINET',
#  '',
#  'NO MOTHER THE MONKEY DOES TRANGS IT OR US',
#  '',
#  'CURTAINS AT THE WINDOWS',
#  'AND THE QIT WEARING SHOES',
#  'THE CHILD HAS GOT IT STOLEN REACHING UP INTO THE COOKYJA',
#  'GT DRI',
#  'GOING ON IN THAT I',
#  'AND TWO FOSCETS WITH EX TYPE HANDLES ONE ON EITHER SIDE AND THE CENTRE FOSCET',
#  '',
#  'A GIRL IS PICKING HER NOSE',
#  'THE WECONSTARTED',
#  'TOSA AL THAN ARE IS A VERY ABSED',
#  'AND IN THE SECOND PICTURE LITTLE GIRLAN WICH OF THOSE TWO DRYING DISHES',
#  "TELL ME EVERYTHING THAT YOU SEE HAPPENING IN THAT PICTURE EVERYTHING THAT'S GOING ON THERE E",
#  'AND ER I SEE CABLETS AROUND THE KITCHEN OTHER CABLETS',
#  '',
#  'HE SOTHOW',
#  'THE KITCHEN THINKIS RUNNING OVER THE WATER RUNNING OUT ON THE FLOOR',
#  'O NO',
#  'THE LADY HERE STANDING RIGHT IN THE WATER',
#  'THE WATER IS RUNNING OVER OUT OF THE SINK',
#  '',
#  'DANNO FER TI OU FOTER',
#  'AND HE SAW THE STOOL AND ITS TURNING OVER',
#  "AND I WANT YOU TO TELL ME EVERYTHING THAT YOU SEE HAPPENING THERE EVERYTHING THAT'S GOING ON",
#  'WHAT DO YOU SEE GOING ON IN THAT PITURE',
#  "MOTHER'S RIGHT FOOT IS FLAT ON THE FLOOR AND HER LEFT SHE'S ON HER LEFT TOE",
#  'AND THE STOOL ON WHICH THE BOY IS STANDING IS ABOUT TO FALL',
#  'THE WINDOW HAS DROPD WITH DRAWN DRAPES',
#  '',
#  'ANYTHING ELSE',
#  'TREE LETEBAT',
#  'O',
#  "YET IT'S NOT REAL CLEARS TO DO WHAT YOU CAN",
#  'NOTTDI',
#  'THOUGH A THREE LEGGED STOL IS COMING DOWN WITH HIM',
#  "AND A THE LITTLE GIRL'S HERE AN THE LITTLE BOY AN HE ALMOST IS FALLIN OFF THE STOOL",
#  '',
#  'AND THE WATER IS OVERFLOWING FROM THE SINK ON TO THE FLOOR',
#  'I ALSO HAVE BELIEVED THAT THE MOTHER IS DAY DREAMING',
#  'A VIVORETE',
#  'I WANT YOU TO TELL ME EVERYTHING THAT YOU SEE HAPPENING IN THAT PICTURE EVERYTHING THAT YOU SEE GOING ON THERE',
#  'ALL OF THE AF',
#  'A',
#  "WHAT'S GOING ON HERE",
#  "I DON'T THINK I HAVE LOST IT",
#  'THE LEBOI STANON ALAN',
#  '',
#  "THRO NO THAT'S",
#  'AH G',
#  "THE LITTLE GIRL'S RAISING HER HANDS FOR THE LITTLE BOY TO HAND HER A COOKIYE",
#  'THE ELWOMAN MOTHER IS DRIR DOCTOR DISH',
#  '',
#  'THE WARKS AO ORE TOO VISIBLE',
#  "SHE'S LOOKING OUT THE WINDOW",
#  'JES WAING AN APRON',
#  "SHE'S DRYIN DISHES",
#  '',
#  "IM WHILS I SAY THAT E YO NOW BOY IM A STAND AR ON THAT STOL EN IT'S TILTON",
#  'THE WOMAN IS DRYING A PLATE',
#  'O',
#  'ALL THE ACTION',
#  "EVERYTHING THAT'S GOING ON IN THERE",
#  'SO IT IS WHOLY A COOKING A TEV PATIN GRAVIS FOR ANOTHERPENC FREND',
#  'HE HAS ONE COOKI IN HIS HAND IS REACHING FOR ANOTHER ONE',
#  "AND THERE'S A DRIVEWAY BORDERED WITH GRASS",
#  'O',
#  'OR BOY',
#  'IT WOULD BE MORE FUN IF YOU HAD SOME FALTO',
#  "PRESUME THAT'S THE LAIRHOUSE",
#  "MAYBE RINHT MABBE IAN'T WATER ON THE SANK IN DE GODFISHIN GOT A GOT TA COE POOL THAT YOU MAYH GET SOME MITE INOT",
#  'WELL THE MOTHER HAS WATER SPILLIN ALL OVER THE FLOOR FOR ONE',
#  "WHAT'S GOING ON",
#  'CAROSALENITE',
#  'AND THE SINKAS BUDDING OVER OVERFLOWING',
#  'FO ME ALL THE ACTION YOU SEE',
#  'WELL THE BOY IS HANDING THE LITTLE GIRL A COOKIE',
#  'IS OF CORS ID RAN',
#  'BY THE RUSSING BISHS',
#  'JU TELL ME ALL OF BE AS',
#  'A TE AT THE TIK IS RUNNING OVER ON THE FLOOR',
#  'TELL ME EVERYTHING YOU SEE HAPPENING IN THE NAT PAGI',
#  'AND MOTHER IS HAVING WATER RUN OVER THE YE SINK',
#  "THAT'S ALL I SEE THERE",
#  "HE'S REACHING IN A COOKYE JAR AND HE HAS A COOKY",
#  "AND THE LITTLE GIRL IS PUTTING HER FINGER TO HER MOUTH BUT SHE'S GOIN TO KEEP IT QUIET",
#  "THERE'S A GLOD BORHER TALKING IN A BULLO BOY I SON WIT TII",
#  'AND THEE TWO CHILDREN EVIDENTLY A BROTHER AND A SISTER ARE GETTING COOKIES OUT OF THE COOKIE JAR WHICH IS ON THE SECOND SHELF OF THE UPPER CUPBOARD',
#  'ANYTHING ELSE',
#  'THIS IS A NICE PLACE FOR AN BUTA WAT THEY HAND',
#  "IT'S ABOUT ALL I CAN SEE ON THAT",
#  "AS HE'S GETTING UP TERE THI THE TOOL OF THE STOOL IS TILTING AND HE LOOKS AS THOUGH HE WERE ABOUT TO FALL OVER",
#  "SHE'S ALSO LOOKING OUT THE WINDOW",
#  'AND WATER DRIPPED ON THE FLOOR',
#  'ELA',
#  'OH HAHA WELL O NOTICE',
#  'AI',
#  'I SE LITTLE BOY ON TETOR  FRAWLING OVER TAKING COOKIES OUT OF THE COOKYE JAR',
#  'WHEN THE WATER IS RUNNING IN THE SINK AND OVERFLOWING ON THE FLOOR AND GETTING HER FEET WET',
#  '',
#  '',
#  'THAT THERE IS A CUP AND A SAUCER ON THE ER SINK BOARD',
#  "HE'S SUPPOSEDLY GOING TO HAND ONE COOKIE IT LOOKS AS THOUGH HE IS TOH HIS SISTER AND GRAB ANOTHER ONE FOR HIMSELF BUT I DOUBT HE'S THAT HE'S GOING TO GET ALL THAT DONE BEFORE THE SCHOOL FALL'S OVER",
#  'EHAS A COOKY JAR OPEN',
#  'BUT THEY SEEM HAPPY IN DOING THEIR OWN THING',
#  '',
#  "AND HE HAS ONE COOKI IN HIS HAND AND HE'S GOING AFTER ANOTHER ONE",
#  "AN AN AND THE MOTHER IS ED THE WATER IS RUNNING OVER  SHE DOESN'T SEEM TO BE AWARE OF IT TOO MUCH",
#  'AND LET SOSTE READ OF A PSALM',
#  "N'T YOU SEE HAPPENING IN THAT PICTURE",
#  'TWO CAPSIN A DISH HE MADE',
#  "WHAT I WAS TO HAVE YOU DO IS WHILE THE REPORTER'S ON I WANT YOU TO TELL ME ALL OF THE ACTION YOU SEE GOING ON IN THE PICTURE",
#  'BTISISTERY NO WONWA IS IT',
#  'O E',
#  'ET OFA MAIMOR',
#  "AND A THE'RE EACH BUSY EXCEPT A SOMETHING",
#  "AT KA THE KID ON THE BENCH WHO'S GOT HIS HAND IN THE COOKIE JAR AND HE'S FALMING OFF HIS SISTER WANTS ONE",
#  '',
#  'YOU LOOK OUT ON THE DRIVEWAY',
#  "AND A SHE HAS ON A SLEEVELESS DRESS WHICH ALSO INDICATES THAT IT'S SUMMER",
#  'MIS TWO BOYS',
#  'A GIVE ME A COOKY DORY',
#  "THERE'S A PLATE AND TWO CUPS ON THE SINKET SHE'S GOT A PLATE IN HER HAND",
#  "'S A DRIVEWAY OR IT LOOKS LIKE A DRIVEWAY OUTSIDE",
#  'AND THE GIRL IS ASKING FOR COOKIE',
#  'EVERYTHING THAT YOU SEE HAPPENING HERE',
#  'DID I TALK ABOUT THIS GIRL YE',
#  'AND THE WINDOW IS OPEN',
#  'THE LETTERS OFF THE COKEE JAR',
#  'WHEN TIS HALF OPEN',
#  'BUT O CARE TANK',
#  'LOOKS AS HOUGH SHE HAS AN APRON ON',
#  'THE FOCITIS RUNNING AND ITS OVERFLOWING ON TO THE FLOOR BECAUSE THEM ITS OVERFLOWING INTO THE SINK',
#  'HEWAS HANDING THE LITTLE GIRL AND COOKIN SID OF THE JAR',
#  "ELEM GET'S READY TO HAND HER GAFU",
#  'POTTY NOL TOMS BED WET SEE WI CRISTEN PUPO DAYS GONE BY THAN ATEM',
#  'KNOW BY LOOKING AT THE',
#  'THE WOMAN LEFT HER OSSAF FRIGTING AND TEN E WOER ALL OVER THE FLOOR',
#  'I CANNOT SEE TO FAE TOT TMA',
#  'O COKEN JOHN',
#  'I STAYD AWAY HARMLESSLY THAT MUCH MOR A AER',
#  "AM WE'RE GETTING SOMETHIN TO EAT HERE",
#  '',
#  'T POF',
#  'AS TE VARI',
#  "THE MOTHER'S WASHING THE DISHES",
#  'AND THE RACE HORSE IS JUMPING THROUGH THE WINDOW',
#  'IM THE WINDOW IS OPEN AND THE CURTAINS ARE BLOWING AND THE BREEZE COMING IN FROM OUTSIDE',
#  '',
#  "MISDEA THIS LITTLE BOY STAYING ON STOOL REACHING FOR COOKIES ATD DIDN'T LOOK LIKE HE WAS READY TO FALL",
#  "EVERYTHING THAT'S GOING ON OW",
#  'SIBEBI',
#  'AN EVERYTHIN E',
#  "THE BOYS UP TE REACHING FOR IT AND LOOKS LIKE HE'S GOING TO FALL OFF WITH TE STOOL",
#  'NETELET ERE TITT ITO PEIN O SHINI S AS MOOTI AS',
#  'A COOKY JAR STEARING  FAW COOKY OUT O COOKYE JAR',
#  "WON'T YOU TELL ME EVERYTHING YOU SEE HAPPENING IN THAT PICTURE",
#  'EN BATERSED',
#  'IS PENIT',
#  '',
#  'A JACK WHAT EOUSSY GOING O',
#  'E MATER OIES',
#  "SHE'S DRYING THE DISHES",
#  'AARS',
#  'OH YES',
#  'HOW E',
#  'THE WATER IS RUNNING OVER OUT OF THE SINK',
#  'WELL AND STILL IN THE WATER AN UNWASHING IN HEDISHES',
#  'THIS TIME',
#  'COVERDS UNDERNESA OTHER COVERTS',
#  '',
#  'C O O K E I E J A R',
#  'EN SHE STARTEN TO DRY THE DISHES',
#  'THE BOY IS STANDING ON HIS RIGHT FOOT',
#  'ANYWHERE',
#  'SO NEY',
#  "I DON'T SEE ANYTHING",
#  'YOU CAN FALL OFF IS STOOL',
#  'THE GIRL LAUGHING O',
#  '',
#  'AH THE WINDOW IS OPEN',
#  'OH',
#  'TO SEIZE REACHING UP THE THAKA COOKIN FROM HIS HAND',
#  'AM AH WATER SINKIS OVERFLOWING',
#  'A CROKOJAR',
#  'AND IT MAKES US STILL WATSHING IDISION AT THE SIGHT GAN',
#  'SPEAR ATED TE HARIER',
#  'ANYTHING ELSE YOU COULD SEE GOING ON',
#  'YERS',
#  'THE SINK IS RUNNING OVER AND DRIPPING WATER ON THE FLOOR WHILE THE MOTHER IS TRYING TO DRY THE DISHES',
#  "I'M LOOKING OUTSIDE BUT THAT YARD IS OK",
#  'AN A SI',
#  'WHAT DO YOU SEE HAPPENING IN NOTHING',
#  'THE BOY HAS TAKEN THE LID OFF A COOKIE JAR HAS COOKY IN HIS LEFT HAND IS REACHING WITH HIS RIGHT HAND FOR ONE',
#  '',
#  'LITLE BOY HAS ONE HAND IN THE COOKY JAR AND ONE WI A COOKY IN IT HANDING UP TO THE LITLE GIRL AS GOT HER HAND UP FOR IT AND HER SHE LOOKS LIKE GOT HER FINGER IN A MOUSE TO TELL HIM TO BE CAREFUL',
#  'OT YO O ANYTHING',
#  "EVERYTHING THAT'S GOING ON",
#  '',
#  "TAKE A LOOK AT THAT AND TELL ME EVERYTHING THAT YOU SEE HAPPENING IN THAT PICTURE EVERYTHING THAT'S GOING ON",
#  'TELL ME EVERYTHING THAT YOU SEE GOING ON IN THIS PICTURE',
#  '',
#  "WHER'S A GIRL",
#  'TUSA A SOME SHRUBBERY UNDERNEATH ANOTHER WINDOW THAT LOOKS ITIN ANOTHER WING OF THE HOUSE',
#  'OR LIKE HER',
#  'OH THE LITTLE GIRLS LAUGHING',
#  "GO I I DON'T KNOW WHETHER SHE'S YOUR FOOD ER ASKING FOR THEM COOKI OR AR TING SOLIKE AFEL II E TON IN TE BETE",
#  'OY',
#  'ISE',
#  'WATER RUN MI',
#  'TELITER OCEPARET OVER  OFF',
#  'CAY',
#  'TAS MIDNIGHT LOT THAT STILL',
#  'LIK SIS WASHING HE DISH IN ISCAT SHE GOT DE DISHES ON THES SITTIN ON THE SAME',
#  'TO RE QOOK A JOR COMANDE TEACHER IN DEATH',
#  '',
#  'CATHIC DOORS ON OF TE SAME FOR DIFFERENT SIZES',
#  '',
#  'AS HE LIFT IT UP A LITTLE',
#  "OH WHAT'S HAPPENED",
#  'WEL THE PAER',
#  'OR AT SHEWAS TO FOR SEEI ASHE',
#  "AND THE LITTLE GIRL SHE'S WAITING FOR THE COOKIE BUT I DON'T THINK SHE'S GOING TO GET INBEFUSS THE BOY'S FALLEN DOWN",
#  '',
#  "AN SHE'S VERY SUR",
#  "SHE'S SHE'S REACHING FOR COOKI",
#  "SHE HAS FLATDER HAN SHE'S DRUNK",
#  'I JUST WANT YOU TO TELL ME EVERYTHING THAT YOU SEE HAPPENING IN THAT PICTURE',
#  'ANYTHING ELSE GOING ON OVER HERE',
#  "THE MOTHER IS WORKING AT THE SINK AND THE FOSSET IS LEFT ON AND APPARENTLY THERE'S NO OVERFLOW IN THE SINK SO IT'S OVERFLOWING RIGHT ON TO THE FLOOR SPLIES PLIS",
#  'THIY MIGHT BEYOND THI SAE',
#  'CON',
#  '',
#  'NO',
#  'TTHAT THE BOY BOY BO  EE O EAR TAT E WAS  FOE ON TE BENCH BUED O O E O E ONTER E  AS WOT SAID ABOUT IT',
#  '',
#  'A NICELY GROWN',
#  '',
#  'ML',
#  'A O',
#  'AA',
#  '',
#  'IP TOSEARIS',
#  'N FALLING AT THE SAME TIME BECAUSE THE STOOL HAS TIPPED OVER',
#  'SHE HAS SHORT HAIR',
#  'CURTAINS AT THE WINDOWS',
#  'A THE BOY IS FALLING OFF THE STOOL STEALING THE COOKIES OUT OF A COOKIE JAR',
#  'T',
#  'THE WIND IS BLOWING THE CURTAINS',
#  'DATTER SHIPIOI',
#  'CAN CONSIDEROR THINGS HE HAPNE',
#  'UT I SAY THE CABINET DOORS KIZAR HAVE NO HANDLES',
#  'A LITTLE GIRL IS REACHING FOR HER BROTHER TO GIVE HER A COOKIE',
#  'NITA LADY STANDING IN THE WATER',
#  '',
#  'HE HAS THE CLOOKI IN HIS HAND',
#  'MOTHER I PRESUME ITS MOTHER IS AT THE SAME',
#  'I GUESS IC O RIN ADIAL',
#  'MOTHERS KAPTRELENOVE ON THE FLOOR',
#  "YE'REN'T GOING TO KNOCK THINGS OFF",
#  'ISON',
#  'OLEO',
#  "AND THEY YELL IHE CURTAINS SEEMD TO BE SHAKING FROM THA WIND AN THE AIR THAT'S BLOWING IN",
#  'AR PETWER',
#  'ESEEKA OR THEFISH',
#  'OTGIN TAIR',
#  'AT LOOK HEN IT LOOKS NICE',
#  'TEN FASE IS HU ESTICULANGAGE',
#  '',
#  "THERE'S A TREE BEYOND",
#  'OH ANYTHING ELSE THAT I MSUPPOSED TO PICK UP',
#  'WHO',
#  "AND THE MORE HE'S REACHING UP FOR COOKIES",
#  'WHILE THE LITTLE GIRL WAS REACHING FOR A COOK',
#  'EVERYTHING AS GOING ON THERE',
#  "WE HAVE HERE A SCENE IN THE KITCHEN AND IT LOOKS AS THOUGH THAT'S A MAMMA WHO IS WORKING AT THE SING AND HER TWO CHILDREN",
#  'AST YOU',
#  'WATERS RUNNING OVERFLOWING SINK',
#  "HE'S RACHING FOR LON FOR HIMSEL",
#  'THERE IS TEN THAT TWO CHILDREN ARE IN THE PROCESS OF STEALING COOKIES FROM THE COOKYE JAR',
#  'ABEATFULNGWAYS KIS MYGER PRIVATE MONETAK',
#  'SHE HAS A DISH TOWEL IN HER HAND WHAT DOING DRYING ONE OF THE DISHES',
#  'AE CUPBOARDS HALF OPEN',
#  'AND THA  THIS HERE ONE GOD ONE ONE ER FALLEN FALLEN DOWNIN THROUGH HER',
#  'M',
#  "AND THERE'S WATER COMING OUT OF THE SPICIT",
#  'TENAT',
#  "AH THERE'S A WINDOW THEREAND SHE'S LOOKING OUT AT THE GRASS AND THE FLOWERS",
#  'AH YOULAGHD USY Y  MY PERSONALO DESCRIPTION',
#  '',
#  '',
#  '',
#  'AND AH THE COOKED JAR HAS LIT',
#  'AN',
#  'THE BOY IS HANDING HER A COOKIE',
#  "THE GIRL IS LIKE SNICKERING AT WHAT'S HAPPENING TO HIM S",
#  "MOCKA IT'S A BOY AND A GIRL AND THEIR MUM",
#  'SO',
#  'THE LITTLE GIRL IS REACHING FOR A COOKIE',
#  'ER THE DRONCIC',
#  'EH THE MOTHER IS LOOKING OUT THE WINDOW WHILE THE WATER RUNS OVER FROM THE SINK',
#  'SAYIN THE MOTHER',
#  "AH IT'S OBVIOUSLY SUMMER BECAUSE THE WINDOW AS I SAID WAS OPEN",
#  'DYO WHAT WAS HAPPENING THERE',
#  "AND THERE'S THE",
#  '',
#  'IS WOMENED BAN BY A SANK RUSH OF VISHES AND THE WATER SPOLLIN OUT O HIS',
#  'E G',
#  'YOSE',
#  'WHILE THE BOY IS EH TAKING COOKIES OUT OF THE COOKIE JAR WHILE THE THE STOOL IS READY TO E FALL OVER',
#  '',
#  'NEARLY ALL THE ACTIONIS BE GOING ON',
#  'ANYTHING ELSE',
#  'A TWO CUPS ON THE COUNTER PLATE',
#  'SHE HAS SHOES ON WITH NO TIES JUS SORT OF SLIP ON SHOES',
#  'STANDING ON A STOOL WHICH IS TIPPING OVER',
#  'PETER',
#  "NOW TELL ME WHAT'S HAPPENED",
#  "AND THERE'S A TREE OUT THERE SOMEWHERE THAT YOU CAN SEE PART OF THE TRUNK AND PART OF THE FOLIAGE",
#  "ANDE THE WATERIS OVERFLOWING ON TO THE FLOOR AND SHE'S STANDING IN THE PUDDLE AND HAS THE SMILE ON HER FACE",
#  "AN HEAV'S ON A A STOOL THAT IS GOING TO FALL OVER WHILLE THERE'S STEAL AN COOKINGS",
#  'A THE NICELY DRESSED KIDS BUT AR THE BOY NEEDS HIS SOCKS PULLED UP',
#  'MAGICATS',
#  "THAT'S ALL THER IS",
#  'A TE ANTO TE LETI',
#  'THE LITTLE GIRL WAS LAUGHING AT HER BROTHER WHO WAS TAKING A COOKIE OUT OF THE COOKIE JAR',
#  'EKIN TABLE BON T WAS FOUND',
#  'AND SHE IS WASHING HOLDING A PLATE IN HER HAND',
#  "SHE'S RABBING FOR THE ONE THAT HE HAS IN HIS LEFT HAND",
#  'ON TIIS WITE NEGRO  OT  RECHIN',
#  'SHE LOD OVE OEHED',
#  'AND YOU ARE ACTUALLY VERY KINDLY THANK YOU',
#  'AM SHE IS DRYING A DISH WITH A TEA TOWEL A PLATE WITH A TEA TOWEL',
#  'EDRIN E DISHE',
#  '',
#  'SISTER AGAINST THEM LAUGHING',
#  'DESTENDING TEWOVEROPE HE SAT QUICKLY JON',
#  'IS',
#  '',
#  'ANYTHING',
#  'DECEVAT',
#  'MOR',
#  "AND THEN THIS HERE WINDE WATER SHOULD BE GOING DOWN IN THERE BUT IT'S GOING DOWN ON THE SIDE HERE",
#  "THE GIRL IS WHISPERIN TO BE QUIET CAUSE MOTHER MIGHT FIND OUT THAT HE'S STANDING ON I COT STOOL WHICH IS BENDING OVER",
#  'FOR YEO',
#  'AND WALK WAY PICTURE FOM THE WEN',
#  'ANDSCOT ONE IN HIS HAND AND HANDING IT TO HIS SISTER',
#  "WHAT'S HAPPENED OR",
#  "THAT SPELL'S SOMTING DOWN THERE BUT I CAN'T SEE IT",
#  '',
#  'TELLME YOL BALOK',
#  "THERE'S KITCHEN CABINETS",
#  'THE LITTLE BOY CLIMBING UP AN SOME COOKED COOKED LAD TO COOK A JOW',
#  'KNOW WAT THOU WATCHING SINGO WAS SMLINGY',
#  'AND THE LITTLE GIRL IS TELLING HIM TO BE QUIET BY PUTTING HER FINGER ON HER LIPS',
#  'HO CARRY',
#  "SHE'S DOING DISHES AND THINKS NOTHING OVER AND WETTING HER FEET",
#  "ANYTHING ELSE THAT'S GOING ON",
#  'S BALANCED TRUE',
#  'HAPPILY',
#  'AOS',
#  'WELL THE SINK IS RUNNING OVER',
#  'WOCAME VERY CAS',
#  'OIS DUKE',
#  'ONLY ALL THE ACTS',
#  'LOOK AT THAT PICTURE AND TELL ME EVERYTHING THAT YOU SEE GOING ON IN THAT PICTURE',
#  'IS I REGAN IS  EGANIT THEN',
#  'O WHITE YELLOW WHAT O BEEPENIN',
#  '',
#  '',
#  'VOTL',
#  'LOD LYING OVER',
#  '',
#  'THE WATER IS RUNNING ON THE FLOOR',
#  'AND HE HIS LADDER SLIPPED FROM UNDERNEATH IM',
#  "BUT O DIDN'T SO",
#  'ON HAV TE NIGHT WEN ON',
#  'FOKE ANYTHING ELSE',
#  'POSTOLY BE WORRYING ABOUT SOMETHING',
#  'A THE SINKS RUNNING OVER',
#  '',
#  '',
#  'BUT YO OWE O SA',
#  '',
#  'FOR ONE THING',
#  'OO',
#  'AND RELLY KILLED',
#  'AA TIS IS THE HIGHES TONILON OF SOME KIN OF ICTURE',
#  'YOUNG BOY IS UP AT THE COOKING JAR',
#  'WHAT',
#  'YEHAH IS THAT IT',
#  'AND IN THE MEANTIME YES TOOPEN HIS CHAIR',
#  'SET',
#  'MOTHER IS DRYING THE DISHES',
#  'THE GIRL IS TOUCHING HER LIPS',
#  "THEN WHEN YOU GET OVER AND HAVE TURNED A CORNER IN THE KITCHEN YOU HAVE VASE CABINETS AND THEN YOU HAVE A WINDOW ABOVE THAT WHICH IS LOOKING OUT INTO SOMETHING WHICH MAKES IT LOOK AS THOUGH IT'S SUMMER OUTSIDE BECAUSE THE WINDOW IS OPEN",
#  'SHE SEEMS TO BE LOOKING OUT THE WINDOW AT THE LAWN',
#  "L L WE WILL PAINT JOHN'S WAGON GREEN L T  ABURDEN",
#  'THEY ALL HAVE SHOES ON',
#  'ANYTHING ELSE',
#  '',
#  'LIKE EPEE REPEATEDY',
#  'THE MOTHER IS DRYING THE DISHES',
#  'COMING BACK TO THE SAINT LA SE HIM',
#  "AND I GUESS THAT'S WAT LOOKS LIKE PART OF THE GARAGE INDER O THE GARAGE I TAR",
#  '',
#  'MUCH THAN KOW',
#  'POOR OLD MOM GOT A GITTER',
#  'A A PARRAT SORTLY TO A SCANDAL FOR DORAS',
#  'OH YES',
#  'HIS LEFT FOOT IS SORT OF UP IN THE AIR',
#  'HAVERKAN',
#  'THERE ARE CUPBOARDS BELOW THE COUNTER AND ABOVE THE COUNTER WHERE THE COOKIES ARE',
#  'MOTHER IS WASHING DISHES',
#  'TER IS NETN',
#  "AND MEANWHILE SHE'S DRYING THE DISHES",
#  "AH AT'S THE SAME FACT",
#  "AND HE'S STEPPING ON US WELL HE'S ON A STOOL BUT IT'S HE'S GOING OVERBOARD",
#  'AND SHE AS A AHAR DE',
#  "WEL THE BOY IS GITTING COOKIES AND HE'S GOIN TO FALL OFF THE STORE",
#  'THIS PICTURE HAS A LOT OF ACTION GOING ON INIT',
#  "CHAIR AND THERE'S WELL E ACTUALLY HAPPENING YOURS",
#  "AT'S A NICE DAY",
#  'S CAN ANYTHING ELSE AY THAT SHOULD HAPPEN',
#  'OE WO YO INCO',
#  "AND SHE'S BEGGING FOR COOKIES THE GIRL",
#  "WELL AT THERE ALLIN N IV A WAY OF MOVEMENT BUT THERE'S A PAIR OF DISHES ON TE",
#  "ONE OF THE LITTLE KID'S FALLING OFF HIS CHAIR",
#  "AND THE SINK IS RUNNING OVER WITH WATER FOR SOME REASON OR OTHER WHILE SHE'S DRYING THE DISH AND LOOKING OUT THE WINDOW AND STEPPING IN A PUDDLE OF WATER",
#  "AIS BOY'S ABOUT TO FALL OFF THE STOOL",
#  '',
#  "WHAT'S HAPPENING OVER HERE",
#  '',
#  'IS AR SUPPOSIN THEY LEAVES ON THE TREES',
#  'AND ICH LANDSCAPE WALLED ARGUED HEL ER',
#  'A',
#  'UP TOWARDS BED',
#  "AND IT'S A NICE DAY OUTSIDE",
#  "AH I GUESS THE MOTHER WOULD BE DOING DISHES AND THE WATER'S OVERFLOWING OUT OF THE SINK",
#  'A NI SA TITE LIVES SUS TIS A REACHIN JOHNNY JOHNNY HES A HES UP ON A LADDOR A GET GETTIN SOME COOKERS IN THAR LIVES SUS TE REACHING UPPE REACH REACHING UP AFE',
#  'WHAR IS SHE',
#  "U BAMMA'S STEPPING IN THE WATER",
#  'AN HAVE NOW LEARNED AN ALABI TO TURN OVER',
#  'I GIRL OSA O',
#  'ARE THE WATER STILL RUNNING IN THE SINK',
#  'WELL FOR ONE THING THE BOY IS STEALING COOKIES']
